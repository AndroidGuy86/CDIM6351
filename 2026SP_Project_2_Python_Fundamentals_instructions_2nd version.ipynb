# %% [markdown]
# <a href="https://colab.research.google.com/github/AndroidGuy86/CDIM6351/blob/main/2026SP_Project_2_Python_Fundamentals_instructions_2nd%20version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project: Python Fundamentals
#
# Google Colab is a free programming environment online. Technically, Colab is a Jupyter notebook hosted online on Google servers. Google Colab is very popular for data analysts and data scientists to experiment with python, machine learning, and visualization. We will use Google Colab to code our python projects and apply what you have learned so far.<br>
#
# If you need help, there are free CIS tutors whose contact info is on WTclass. The instructor is also available to help. <br>
#
# Complete the various tasks below.

# %% [markdown]
# ## Copy This Colab So You Can Edit
# Copy instructor's Colab notebook to your own so you can edit your notebook by clicking File, Save A Copy In Drive.

# %% [markdown]
# ### How to use Google Colab
# Please watch this 12 minute video on how to use Google Colab. https://www.screencast.com/t/K5wrSOjTGG1F
#
# The video's learning objectives are as follows:
#
# 1. What is Colab?
# 2. How to add a code cell or text cell
# 3. How to execute a code cell with the play button or with CTRL+Enter
# 4. Use ! to run a terminal command
# 5. Use HTML or Markdown to format a text cell
# 6. Share a Colab notebook with someone else
# 7. Manage the runtime session and properly disconnect when finished
# 8. Manage, upload, and download files in your runtime session
#
# ### Useful Shortcuts
# CTRL-Enter        run code in the current cell<br>
# CTRL-/     convert line of code to comment or uncomment<br>
# CTRL-M then B   insert cell below (hold control key while you tap m key then tap b key)<br>
# CTRL-M then A   insert cell above<br>
# CTRL-M then  D   delete current cell<br>
# CTRL-S     Save<br>
# ESC        Escapes and exits the command cell or text cell<br>

# %% [markdown]
# ##Task A: Create a WordCloud visualization
# To familiarize youself with Google Colab environment, please replicate the code in Figure 1. You can change the text variable if desired. You do not need to type the green comments, although they explain each line of code. Run your code to see the results. <br>
# Figure 1. Code for Task A.<br>
# <img src="https://raw.githubusercontent.com/sean-humpherys/randomfilestorage/main/word_cloud_spounge_bob_code.png">

# %%
# Type your code for Task A below here:
import matplotlib.pyplot as plt
from wordcloud import WordCloud

text = "ocean waves sand sun surf beach seashells dolphins tides saltwater palm trees sunscreen volleyball pier boardwalk coral reef snorkeling swimming relaxing sunset paradise paradise paradise beach beach beach ocean ocean waves waves"

wc = WordCloud(
    background_color="midnightblue",   # deep ocean blue background
    colormap="cool",                    # cool blues and purples for the words
    repeat=True,
    width=900,
    height=450,
    max_words=80
)
wc.generate(text)

plt.axis("off")
plt.title("A Day at the Beach", fontsize=20, color="white",
          fontweight="bold", pad=15,
          bbox=dict(facecolor="steelblue", edgecolor="white", boxstyle="round,pad=0.5"))
plt.imshow(wc)
plt.tight_layout()
plt.show()

# %% [markdown]
# After completing Task A, learn the following. Click run to see the result of the following code.

# %%
# Learn how to combine strings and numbers using string interpolation
inflation_rate = 0.083
print(f'The inflation rate in the USA for 2022 was {inflation_rate}')  # the f instructs print() to use string interpolation, i.e., insert a variable's value inside a string. Put the variable name inside { }
print(f'An inflation rate of {inflation_rate} means consumer buying power is weakened.')
# Out:
# The inflation rate in the USA for 2022 was 0.083
# An inflation rate of 0.083 means consumer buying power is weakened.

# %%
# Lean how to format float numbers with decimal places
grams = 15.125
print(f'Weight is {grams}')  # no formating
print(f'Weight is {grams:.2f}') # formated with two decimal places
print(f'Weight is {grams:.4f}') # 4 decimals
print(f'Weight is {grams:.0f}') # zero decimals
# Out:
# Weight is 15.125
# Weight is 15.12
# Weight is 15.1250
# Weight is 15

# %% [markdown]
# ## Task B. Grocery Receipt
# Pretend you are a developer and have the task of coding a printable receipt for a grocery checkout system. Code the following steps using the knowledge you have. <br>
# 1. declare a string variable called `card_number`. Assign a value of `'xxx8974'`
# 2. declare a string variable called `date` and assign a string value of `'9-7-2024'`. You do not need to use a date class variable as we have not learned that data type yet. Use a simple string variable.
# 3. declare a <a href="https://campus.datacamp.com/courses/intro-to-python-for-data-science/chapter-1-python-basics?ex=6">float number variable</a> called `cookies_cost` and assign value of `3.15`
# 4. Save and test frequently to catch errors early
# 5. declare a `float` number variable called `chips_cost` and assign value of `4.58`
# 6. declare a `float` number variable called `salsa_cost` and assign value of `5.10`
# 7. declare a `float` number variable called `total_cost` and assign a value that *adds* `cookies_cost` plus `ships_cost plus salsa_cost`.
# 8. Use multiple `print()` functions on multiple lines to print the a receipt as exampled in Figure 2.
# 9. Consider using <a href="https://www.datacamp.com/tutorial/python-string-format">string interpolation to combine text and number variables</a> on the same line. String interpolation example:
# `print(f'Borrower does not qualify at {rate}')`
# 10. Print the numbers with two decimal places (see the example above). <br>
# Figure 2: Output should look like this figure.
# ```
# Receipt
# Date: 9-7-2024
# cookies $ 3.15
# chips $ 4.58
# salsa $ 5.10
# Total: $ 12.83
# ```

# %%
card_number  = 'xxx8974'
date         = '9-7-2024'
cookies_cost = 3.15
chips_cost   = 4.58
salsa_cost   = 5.10
total_cost   = cookies_cost + chips_cost + salsa_cost

print('==============================')
print('      SUNSHINE MARKET 🌞      ')
print('   123 Coastal Ave, TX 78701  ')
print('==============================')
print(f'  Date:         {date}')
print(f'  Card:         {card_number}')
print('------------------------------')
print(f'  Cookies     $ {cookies_cost:.2f}')
print(f'  Chips       $ {chips_cost:.2f}')
print(f'  Salsa       $ {salsa_cost:.2f}')
print('------------------------------')
print(f'  Total:      $ {total_cost:.2f}')
print('==============================')
print('   Thank you for shopping!    ')
print('    See you at the beach! 🌊  ')
print('==============================')
# Out:
# ...
#       SUNSHINE MARKET 🌞
#    123 Coastal Ave, TX 78701
# ...
#   Date:         9-7-2024
#   Card:         xxx8974
# ------------------------------
#   Cookies     $ 3.15
#   Chips       $ 4.58
#   Salsa       $ 5.10
# ------------------------------
#   Total:      $ 12.83
# ...
#    Thank you for shopping!
#     See you at the beach! 🌊
# ...

# %% [markdown]
# ##Task C. Shipping Logic
# Scenario: You are developing code to calculate shipping costs based on a shipping destination. The user needs code that will print the message 'Shipping to UT costs $13.75'  substituting the correct cost for a particular state. Write code to satisfy the following user requirements.
#
# 1. A ship_to_state variable has already been coded for you and will have a different value each time you run your code. Do NOT ask the user to input the shipping state.
# 2. Create a variable called shipping_cost and assigning it a default value of 0.
# 2. Write an <a href="https://campus.datacamp.com/courses/intermediate-python/logic-control-flow-and-filtering?ex=9">if, elif, else clause</a> to handle the following logic: <br>
# If the ship_to_state is TX, NM, CO, or LA, the shipping cost should be 0. <br>
# If the ship_to_state is WA, the shipping cost should be 9<br>
# If the ship_to_state is AK, the shipping cost should be 16.15<br>
# If the ship_to_state is HI, the shipping cost should be 22<br>
# All other states should default to 13.75<br>
# 2. Print the output 'Shipping to TX costs $ 0.00'  substituting the appropriate state abbreviation and cost.
# 3. Format the output to include a dollar sign and format the number with two decimal places. Use string interpolation as examples above.
#
# See Figure 3. Sample Output for Task C.<br>
# If the ship to state is OK, your code will output the following.
# ```
# 'Shipping to OK costs $ 0.00'
# ```
# If the ship to state is WA, your code will output the following.
# ```
# 'Shipping to WA costs $ 9.00'
# ```
# If the ship to state is HI, your code will output the following.
# ```
# 'Shipping to HI costs $ 22.00'
# ```
# Remember that instructor's prewritten code will select the state randomly from the list of possible states. Run your code multiple times and see that the resulting output changes accordingly.

# %%
# DO NOT CHANGE THE FOLLOWING THREE LINES OF CODE
import random
possible_states = ['TX', 'NM', 'OK', 'CO', 'LA', 'WA', 'AK', 'HI', 'UT', 'SD', 'KY', 'FL' ]
ship_to_state = random.choice(possible_states) # randomly chooses a state to test many possible ship to locations

# WRITE YOUR CODE FOR TASK C BELOW HERE
shipping_cost = 0

if ship_to_state in ['TX', 'NM', 'CO', 'LA']:
    shipping_cost = 0
elif ship_to_state == 'WA':
    shipping_cost = 9
elif ship_to_state == 'AK':
    shipping_cost = 16.15
elif ship_to_state == 'HI':
    shipping_cost = 22
else:
    shipping_cost = 13.75

print('==============================')
print('     SHIPPING CALCULATOR      ')
print('==============================')
print(f'  Destination:     {ship_to_state}')
print(f'  Shipping Cost: $ {shipping_cost:.2f}')

if shipping_cost == 0:
    print('  ✅ FREE shipping to your state!')
elif shipping_cost <= 13.75:
    print('  📦 Standard regional rate applied.')
else:
    print('  ✈️  Extended distance rate applied.')

print('==============================')
print(f'  Shipping to {ship_to_state} costs $ {shipping_cost:.2f}')
print('==============================')
# Out:
# ...
#      SHIPPING CALCULATOR
# ...
#   Destination:     SD
#   Shipping Cost: $ 13.75
#   📦 Standard regional rate applied.
# ...
#   Shipping to SD costs $ 13.75
# ...

# %% [markdown]
# ##Deliverable:
# 1. Change the share option to "Anyone with link can view" (top right corner)
# 2. Submit the URL to your Colab notebook to \\WTclass\cidm6303\lessons\Projects\Project 2\
#
# ##Grading Rubric:
# Task A is worth 20%.<br>
# Task B is worth 30%.<br>
# Task C is worth 50%. <br>
# Each is graded pass or fail for code that accomplished the requirements and free from error. You may attempt multiple times.
